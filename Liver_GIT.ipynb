# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings ("ignore")

# %%
liverdata = pd.read_csv("Indian Liver Patient Dataset (ILPD).csv")
liverdata.head()
# Out:
#    65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0  62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1  62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2  58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3  72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4  46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1

# %%
liverdata.describe()
# Out:
#                65         0.7         0.1          187           16  \
# count  582.000000  582.000000  582.000000   582.000000   582.000000
# mean    44.711340    3.303265    1.488488   290.754296    80.824742
# std     16.181921    6.213926    2.810324   243.108929   182.757696
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.250000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     57.750000    2.600000    1.300000   298.000000    60.750000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#                 18         6.8         3.3         0.9           1
# count   582.000000  582.000000  582.000000  578.000000  582.000000
# mean    110.068729    6.482646    3.141581    0.947145    1.286942
# std     289.141876    1.086306    0.796176    0.319863    0.452723
# min      10.000000    2.700000    0.900000    0.300000    1.000000
# ...

# %%
liverdata.shape
# Out:
# (582, 11)

# %%
liverdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   65      582 non-null    int64
#  1   Female  582 non-null    object
#  2   0.7     582 non-null    float64
#  3   0.1     582 non-null    float64
#  4   187     582 non-null    int64
#  5   16      582 non-null    int64
#  6   18      582 non-null    int64
#  7   6.8     582 non-null    float64
#  8   3.3     582 non-null    float64
#  9   0.9     578 non-null    float64
#  10  1       582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
liverdata.columns = ["Age","Gender","Total_Bilirubin","Direct_Bilirubin","Alkaline_Phosphotase","Alamine_Aminotransferase","Aspartate_Aminotransferase","Total_Protiens","Albumin","Albumin_and_Globulin_Ratio","Dataset"]
liverdata
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62   Male             10.9               5.5                   699
# 1     62   Male              7.3               4.1                   490
# 2     58   Male              1.0               0.4                   182
# 3     72   Male              3.9               2.0                   195
# 4     46   Male              1.8               0.7                   208
# ..   ...    ...              ...               ...                   ...
# 577   60   Male              0.5               0.1                   500
# 578   40   Male              0.6               0.1                    98
# 579   52   Male              0.8               0.2                   245
# 580   31   Male              1.3               0.5                   184
# 581   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
liverdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         582 non-null    int64
#  1   Gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphotase        582 non-null    int64
#  5   Alamine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  578 non-null    float64
#  10  Dataset                     582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
#Only Albumin_and_Globulin_Ratio has 4 missing values

# %%
liverdata[liverdata['Albumin_and_Globulin_Ratio'].isnull()]
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 208   45  Female              0.9               0.3                   189
# 240   51    Male              0.8               0.2                   230
# 252   35  Female              0.6               0.2                   180
# 311   27    Male              1.3               0.6                   106
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 208                        23                          33             6.6
# 240                        24                          46             6.5
# 252                        12                          15             5.2
# 311                        25                          54             8.5
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 208      3.9                         NaN        1
# 240      3.1                         NaN        1
# 252      2.7                         NaN        2
# ...

# %%
liverdata["Albumin_and_Globulin_Ratio"] = liverdata.Albumin_and_Globulin_Ratio.fillna(liverdata['Albumin_and_Globulin_Ratio'].mean())

# %%
liverdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         582 non-null    int64
#  1   Gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphotase        582 non-null    int64
#  5   Alamine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  582 non-null    float64
#  10  Dataset                     582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
liverdata.head()
# Out:
#    Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   62   Male             10.9               5.5                   699
# 1   62   Male              7.3               4.1                   490
# 2   58   Male              1.0               0.4                   182
# 3   72   Male              3.9               2.0                   195
# 4   46   Male              1.8               0.7                   208
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        64                         100             7.5
# 1                        60                          68             7.0
# 2                        14                          20             6.8
# 3                        27                          59             7.3
# 4                        19                          14             7.6
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.2                        0.74        1
# ...

# %%
liverdata.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  582.000000       582.000000        582.000000            582.000000
# mean    44.711340         3.303265          1.488488            290.754296
# std     16.181921         6.213926          2.810324            243.108929
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.250000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     57.750000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                582.000000                  582.000000      582.000000
# mean                  80.824742                  110.068729        6.482646
# ...

# %%
liverdata.isna().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
corrmat = liverdata.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(liverdata[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
liverdata.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
# checking dataset is balanced or not
true_count = len(liverdata.loc[liverdata['Dataset'] == 1])
false_count = len(liverdata.loc[liverdata['Dataset'] == 2])

# %%
true_count, false_count
# Out:
# (415, 167)

# %%
# plotting graph for output classes counts
sns.countplot(x = 'Dataset',data = liverdata)
# Out:
# <AxesSubplot:xlabel='Dataset', ylabel='count'>

# %%
sns.countplot('Gender', data = liverdata, hue = 'Dataset')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.pairplot(liverdata, hue = 'Dataset')

# %%
#Only gender is object valued so we convert it to numeric

# %%
liverdata = pd.get_dummies(liverdata, columns = ['Gender'])

# %%
liverdata.head()
# Out:
#    Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   62             10.9               5.5                   699
# 1   62              7.3               4.1                   490
# 2   58              1.0               0.4                   182
# 3   72              3.9               2.0                   195
# 4   46              1.8               0.7                   208
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        64                         100             7.5
# 1                        60                          68             7.0
# 2                        14                          20             6.8
# 3                        27                          59             7.3
# 4                        19                          14             7.6
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset  Gender_Female  Gender_Male
# ...

# %%
liverdata.shape
# Out:
# (582, 12)

# %%
liverdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         582 non-null    int64
#  1   Total_Bilirubin             582 non-null    float64
#  2   Direct_Bilirubin            582 non-null    float64
#  3   Alkaline_Phosphotase        582 non-null    int64
#  4   Alamine_Aminotransferase    582 non-null    int64
#  5   Aspartate_Aminotransferase  582 non-null    int64
#  6   Total_Protiens              582 non-null    float64
#  7   Albumin                     582 non-null    float64
#  8   Albumin_and_Globulin_Ratio  582 non-null    float64
#  9   Dataset                     582 non-null    int64
#  10  Gender_Female               582 non-null    uint8
#  11  Gender_Male                 582 non-null    uint8
# dtypes: float64(5), int64(5), uint8(2)
# memory usage: 46.7 KB

# %%
liverdata.columns
# Out:
# Index(['Age', 'Total_Bilirubin', 'Direct_Bilirubin', 'Alkaline_Phosphotase',
#        'Alamine_Aminotransferase', 'Aspartate_Aminotransferase',
#        'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio', 'Dataset',
#        'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
feature_columns = ['Age', 'Total_Bilirubin', 'Direct_Bilirubin','Alkaline_Phosphotase', 'Alamine_Aminotransferase',
                   'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin', 'Albumin_and_Globulin_Ratio',
                   'Gender_Female', 'Gender_Male']
predicted_class = ['Dataset']

# %%
X = liverdata[feature_columns]
y = liverdata[predicted_class]

# %%
#Oversampling to have balanced data before proceeding

# %%
from imblearn.over_sampling import SMOTE
smk = SMOTE(random_state = 10)
X, y = smk.fit_resample(X,y)
X.shape, y.shape
# Out:
# ((830, 11), (830, 1))

# %%
# from imblearn.under_sampling import NearMiss
# nm = NearMiss()
# X, y = nm.fit_resample(X,y)
# X.shape, y.shape

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state=10)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((498, 11), (332, 11), (498, 1), (332, 1))

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier(random_state=1)

model = random_forest_model.fit(X_train, y_train)

# %%
predict_train_data = model.predict(X_test)

from sklearn import metrics

print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.792

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, predict_train_data)
cm
# Out:
# array([[127,  39],
#        [ 30, 136]], dtype=int64)

# %%
from sklearn.ensemble import ExtraTreesClassifier

model_1 = ExtraTreesClassifier(random_state=70)
model_1.fit(X_train, y_train)
predict_train_data = model_1.predict(X_test)
print("Accuracy = {0:.3f}".format(metrics.accuracy_score(y_test, predict_train_data)))
# Out:
# Accuracy = 0.798
